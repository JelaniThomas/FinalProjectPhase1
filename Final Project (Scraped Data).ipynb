# %% [markdown]
# # MicroFilms: 2019 Box Office Scraped Data

# %% [markdown]
# This notebook is compiled of the scraped data from the top 100 Worlwide Grossing Movies in 2019, according to www.the-numbers.com.

# %%
#Import libraries
import requests 
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %% [markdown]
# #### Here we're scraping the website for the 2019 Box Office records

# %%
#Testing to confirm the response from the website. 200 Response means we're good to go.
url = 'https://www.the-numbers.com/box-office-records/worldwide/all-movies/cumulative/released-in-2019'
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
#Using BeautifulSoup to scrape the website
soup = BeautifulSoup(response.content, 'html.parser')

# %%
#Scraping the Rank, Movie, Worldwide Box Office, Domestic Box Office, International Box Office & Domestic Share
film=[]
for row in soup.find('div', id = 'main').findAll('td')[3:]:
    film.append(row.text)    
film
# Out:
# ['1',
#  'Avengers: Endgame',
#  '$2,797,800,564',
#  '$858,373,000',
#  '$1,939,427,564',
#  '30.68%',
#  '2',
#  'The Lion King',
#  '$1,654,381,934',
#  '$543,638,043',
#  '$1,110,743,891',
#  '32.86%',
#  '3',
#  'Frozen II',
#  '$1,447,244,586',
#  '$477,373,578',
#  '$969,871,008',
#  '32.99%',
#  '4',
#  'Spider-Man: Far From Home',
#  '$1,131,219,645',
#  '$390,532,085',
#  '$740,687,560',
#  '34.52%',
#  '5',
#  'Captain Marvel',
#  '$1,129,727,388',
#  '$426,829,839',
#  '$702,897,549',
#  '37.78%',
#  '6',
#  'Toy Story 4',
#  '$1,073,080,329',
#  '$434,038,008',
#  '$639,042,321',
#  '40.45%',
#  '7',
#  'Star Wars: The Rise of Skywalker',
#  '$1,072,944,222',
#  '$515,202,542',
#  '$557,741,680',
#  '48.02%',
#  '8',
#  'Joker',
#  '$1,072,507,517',
#  '$335,451,311',
#  '$737,056,206',
#  '31.28%',
#  '9',
#  'Aladdin',
#  '$1,046,759,512',
#  '$355,559,216',
#  '$691,200,296',
#  '33.97%',
#  '10',
#  'Jumanji: The Next Level',
#  '$800,128,637',
#  '$316,831,246',
#  '$483,297,391',
#  '39.60%',
#  '11',
#  'Fast & Furious Presents: Hobbs & Shaw',
#  '$760,372,607',
#  '$173,956,935',
#  '$586,415,672',
#  '22.88%',
#  '12',
#  'Ne Zha Zhi Mo Tong Jiang Shi',
#  '$742,514,069',
#  '$3,695,533',
#  '$738,818,536',
#  '0.50%',
#  '13',
#  'Liu Lang Di Qiu',
#  '$727,714,822',
#  '$5,875,487',
#  '$721,839,335',
#  '0.81%',
#  '14',
#  'How to Train Your Dragon: The Hidden World',
#  '$522,587,135',
#  '$160,799,505',
#  '$361,787,630',
#  '30.77%',
#  '15',
#  'Maleficent: Mistress of Evil',
#  '$489,346,495',
#  '$113,929,605',
#  '$375,416,890',
#  '23.28%',
#  '16',
#  'It: Chapter Two',
#  '$469,566,806',
#  '$211,593,228',
#  '$257,973,578',
#  '45.06%',
#  '17',
#  'Wo he wo de zu guo',
#  '$465,418,019',
#  '$2,323,409',
#  '$463,094,610',
#  '0.50%',
#  '18',
#  'The Secret Life of Pets 2',
#  '$446,272,914',
#  '$158,874,395',
#  '$287,398,519',
#  '35.60%',
#  '19',
#  'PokÃ©mon: Detective Pikachu',
#  '$432,142,736',
#  '$144,105,346',
#  '$288,037,390',
#  '33.35%',
#  '20',
#  'Zhongguo jizhang',
#  '$417,850,370',
#  '$706,572',
#  '$417,143,798',
#  '0.17%',
#  '21',
#  'Alita: Battle Angel',
#  '$401,900,040',
#  '$85,838,210',
#  '$316,061,830',
#  '21.36%',
#  '22',
#  'Godzilla: King of the Monsters',
#  '$383,299,915',
#  '$110,500,138',
#  '$272,799,777',
#  '28.83%',
#  '23',
#  'Once Upon a Timeâ\x80¦in Hollywood',
#  '$377,312,380',
#  '$142,502,728',
#  '$234,809,652',
#  '37.77%',
#  '24',
#  '1917',
#  '$366,890,181',
#  '$159,227,644',
#  '$207,662,537',
#  '43.40%',
#  '25',
#  'Shazam!',
#  '$363,664,533',
#  '$140,371,656',
#  '$223,292,877',
#  '38.60%',
#  '26',
#  'Dumbo',
#  '$353,166,307',
#  '$114,766,307',
#  '$238,400,000',
#  '32.50%',
#  '27',
#  'Feng Kuang De Wai Xing Ren',
#  '$326,150,303',
#  '',
#  '$326,150,303',
#  '',
#  '28',
#  'John Wick: Chapter 3 â\x80\x94 Parabellum',
#  '$325,674,995',
#  '$171,016,727',
#  '$154,658,268',
#  '52.51%',
#  '29',
#  'Knives Out',
#  '$312,722,695',
#  '$165,364,060',
#  '$147,358,635',
#  '52.88%',
#  '30',
#  'Us',
#  '$256,091,919',
#  '$175,084,580',
#  '$81,007,339',
#  '68.37%',
#  '31',
#  'Fei Chi Ren Sheng',
#  '$255,832,826',
#  '',
#  '$255,832,826',
#  '',
#  '32',
#  'Gisaengchung',
#  '$254,688,898',
#  '$53,369,745',
#  '$201,319,153',
#  '20.95%',
#  '33',
#  'Men in Black: International',
#  '$253,020,464',
#  '$80,001,807',
#  '$173,018,657',
#  '31.62%',
#  '34',
#  'Terminator: Dark Fate',
#  '$250,372,367',
#  '$62,253,077',
#  '$188,119,290',
#  '24.86%',
#  '35',
#  'Glass',
#  '$246,999,039',
#  '$111,048,468',
#  '$135,950,571',
#  '44.96%',
#  '36',
#  'Dark Phoenix',
#  '$246,356,895',
#  '$65,845,974',
#  '$180,510,921',
#  '26.73%',
#  '37',
#  'Lie huo ying xiong',
#  '$245,179,530',
#  '$290,217',
#  '$244,889,313',
#  '0.12%',
#  '38',
#  'Shao Nian De Ni',
#  '$230,096,929',
#  '$1,921,657',
#  '$228,175,272',
#  '0.84%',
#  '39',
#  'Annabelle Comes Home',
#  '$228,517,113',
#  '$74,152,591',
#  '$154,364,522',
#  '32.45%',
#  '40',
#  'Ford v. Ferrari',
#  '$224,418,748',
#  '$117,624,357',
#  '$106,794,391',
#  '52.41%',
#  '41',
#  'Little Women',
#  '$218,786,590',
#  '$108,095,955',
#  '$110,690,635',
#  '49.41%',
#  '42',
#  'The Addams Family',
#  '$200,612,027',
#  '$97,864,733',
#  '$102,747,294',
#  '48.78%',
#  '43',
#  'Wu Sha',
#  '$199,276,793',
#  '',
#  '$199,276,793',
#  '',
#  '44',
#  'Downton Abbey',
#  '$194,694,724',
#  '$96,853,865',
#  '$97,840,859',
#  '49.75%',
#  '45',
#  'Yip Man 4',
#  '$192,617,891',
#  '$3,956,031',
#  '$188,661,860',
#  '2.05%',
#  '46',
#  'Rocketman',
#  '$192,137,020',
#  '$96,368,160',
#  '$95,768,860',
#  '50.16%',
#  '47',
#  'Tenki no Ko',
#  '$190,527,439',
#  '$7,798,703',
#  '$182,728,736',
#  '4.09%',
#  '48',
#  'The LEGO Movie 2: The Second Part',
#  '$190,131,036',
#  '$105,806,508',
#  '$84,324,528',
#  '55.65%',
#  '49',
#  'Abominable',
#  '$188,125,862',
#  '$60,761,390',
#  '$127,364,472',
#  '32.30%',
#  '50',
#  'The White Storm 2: Drug Lords',
#  '$185,427,900',
#  '',
#  '$185,427,900',
#  '',
#  '51',
#  'Pan Deng Zhe',
#  '$171,110,959',
#  '$487,157',
#  '$170,623,802',
#  '0.28%',
#  '52',
#  'Gemini Man',
#  '$166,623,705',
#  '$48,546,770',
#  '$118,076,935',
#  '29.14%',
#  '53',
#  'Spies in Disguise',
#  '$165,139,629',
#  '$66,757,013',
#  '$98,382,616',
#  '40.42%',
#  '54',
#  'Escape Room',
#  '$155,313,078',
#  '$57,000,756',
#  '$98,312,322',
#  '36.70%',
#  '55',
#  'Yesterday',
#  '$153,108,647',
#  '$73,286,650',
#  '$79,821,997',
#  '47.87%',
#  '56',
#  'The Angry Birds Movie 2',
#  '$152,012,772',
#  '$41,657,076',
#  '$110,355,696',
#  '27.40%',
#  '57',
#  'Hustlers',
#  '$150,472,713',
#  '$104,963,598',
#  '$45,509,115',
#  '69.76%',
#  '58',
#  'Ad Astra',
#  '$135,432,019',
#  '$50,188,370',
#  '$85,243,649',
#  '37.06%',
#  '59',
#  'Angel Has Fallen',
#  '$133,365,452',
#  '$69,030,436',
#  '$64,335,016',
#  '51.76%',
#  '60',
#  'Yin He Bu Xi Ban',
#  '$127,897,924',
#  '',
#  '$127,897,924',
#  '',
#  '61',
#  'Midway',
#  '$126,151,409',
#  '$56,846,802',
#  '$69,304,607',
#  '45.06%',
#  '62',
#  'The Upside',
#  '$125,818,440',
#  '$108,235,497',
#  '$17,582,943',
#  '86.03%',
#  '63',
#  'Extreme Crisis',
#  '$124,169,976',
#  '',
#  '$124,169,976',
#  '',
#  '64',
#  'Last Christmas',
#  '$123,432,533',
#  '$35,150,750',
#  '$88,281,783',
#  '28.48%',
#  '65',
#  'Zombieland: Double Tap',
#  '$122,266,018',
#  '$73,118,130',
#  '$49,147,888',
#  '59.80%',
#  '66',
#  'The Curse of La Llorona',
#  '$121,661,395',
#  '$54,733,739',
#  '$66,927,656',
#  '44.99%',
#  '67',
#  'Meitantei Conan: Konjo no Fisuto',
#  '$117,888,768',
#  '',
#  '$117,888,768',
#  '',
#  '68',
#  'Dora and the Lost City of Gold',
#  '$117,419,117',
#  '$60,477,943',
#  '$56,941,174',
#  '51.51%',
#  '69',
#  'Geukhanjikeob',
#  '$116,127,561',
#  '$1,565,885',
#  '$114,561,676',
#  '1.35%',
#  '70',
#  'Fan Tan Feng Bao 4',
#  '$115,687,407',
#  '',
#  '$115,687,407',
#  '',
#  '71',
#  'Wonder Park',
#  '$115,112,118',
#  '$45,216,793',
#  '$69,895,325',
#  '39.28%',
#  '72',
#  'The Gentlemen',
#  '$113,876,604',
#  '$36,471,796',
#  '$77,404,808',
#  '32.03%',
#  '73',
#  'Boonie Bears: Blast Into The Past',
#  '$112,306,488',
#  '',
#  '$112,306,488',
#  '',
#  '74',
#  'Pet Sematary',
#  '$111,809,732',
#  '$54,724,696',
#  '$57,085,036',
#  '48.94%',
#  '75',
#  'Good Boys',
#  '$111,173,598',
#  '$83,140,306',
#  '$28,033,292',
#  '74.78%',
#  '76',
#  'Chong Ai',
#  '$99,550,121',
#  '',
#  '$99,550,121',
#  '',
#  '77',
#  'Shi Tu Xing Zhe 2 Die Ying Xing Dong',
#  '$98,444,408',
#  '$296,751',
#  '$98,147,657',
#  '0.30%',
#  '78',
#  'The Hustle',
#  '$97,409,779',
#  '$35,417,038',
#  '$61,992,741',
#  '36.36%',
#  '79',
#  'Scary Stories to Tell in the Dark',
#  '$95,607,360',
#  '$68,947,075',
#  '$26,660,285',
#  '72.11%',
#  '80',
#  'XÄ«n xÇ\x90jÃ¹ zhÄ« wÃ¡ng',
#  '$92,796,952',
#  '',
#  '$92,796,952',
#  '',
#  '81',
#  'Five Feet Apart',
#  '$92,554,209',
#  '$45,729,221',
#  '$46,824,988',
#  '49.41%',
#  '82',
#  'Rambo: Last Blood',
#  '$91,419,352',
#  '$44,819,352',
#  '$46,600,000',
#  '49.03%',
#  '83',
#  'Crawl',
#  '$90,007,532',
#  '$39,014,193',
#  '$50,993,339',
#  '43.35%',
#  '84',
#  'Jojo Rabbit',
#  '$87,068,472',
#  '$33,370,906',
#  '$53,697,566',
#  '38.33%',
#  '85',
#  'Wan PÄ«su SutanpÄ«do',
#  '$84,372,709',
#  '',
#  '$84,372,709',
#  '',
#  '86',
#  'A Dogâ\x80\x99s Way Home',
#  '$81,152,505',
#  '$41,952,715',
#  '$39,199,790',
#  '51.70%',
#  '87',
#  'A Dogâ\x80\x99s Journey',
#  '$77,421,192',
#  '$22,782,371',
#  '$54,638,821',
#  '29.43%',
#  '88',
#  'Cats',
#  '$75,486,351',
#  '$27,166,770',
#  '$48,319,581',
#  '35.99%',
#  '89',
#  'Tyler Perryâ\x80\x99s A Madea Family Funeral',
#  '$74,781,999',
#  '$73,257,045',
#  '$1,524,954',
#  '97.96%',
#  '90',
#  "Qu'est-ce qu'on a encore fait au bon dieu?",
#  '$74,766,188',
#  '',
#  '$74,766,188',
#  '',
#  '91',
#  'Charlieâ\x80\x99s Angels',
#  '$73,180,003',
#  '$17,801,306',
#  '$55,378,697',
#  '24.33%',
#  '92',
#  'Doctor Sleep',
#  '$71,856,239',
#  '$31,581,712',
#  '$40,274,527',
#  '43.95%',
#  '93',
#  'What Men Want',
#  '$69,911,903',
#  '$54,611,903',
#  '$15,300,000',
#  '78.12%',
#  '94',
#  'A Beautiful Day in the Neighborhood',
#  '$68,406,338',
#  '$61,696,436',
#  '$6,709,902',
#  '90.19%',
#  '95',
#  'Bai She: Yuan Qi',
#  '$68,364,730',
#  '$34,730',
#  '$68,330,000',
#  '0.05%',
#  '96',
#  'ek-si-teu',
#  '$67,044,017',
#  '$478,949',
#  '$66,565,068',
#  '0.71%',
#  '97',
#  'Happy Death Day 2U',
#  '$64,686,515',
#  '$28,148,130',
#  '$36,538,385',
#  '43.51%',
#  '98',
#  'Eiga Doraemon: Nobita no Getsumen Tansaki',
#  '$63,191,904',
#  '',
#  '$63,191,904',
#  '',
#  '99',
#  'Cold Pursuit',
#  '$62,599,159',
#  '$32,138,862',
#  '$30,460,297',
#  '51.34%',
#  '100',
#  'Bombshell',
#  '$61,404,394',
#  '$31,762,808',
#  '$29,641,586',
#  '51.73%']

# %%
#Convert scraped list into DataFrame
num1=0
num2=6
movies=[]
for num in range(len(soup.find('div', id = 'main').findAll('td')[3:])//6):
    movies.append(film[num1:num2])
    num1+=6
    num2+=6
        
df = pd.DataFrame(movies)
df.columns = ['Rank', 
              'Movie', 
              'Worldwide Box Office', 
              'Domestic Box Office', 
              'International Box Office',
              'Domestic Share']

# %%
#Convert Dataframe to CSV File
df.to_csv('2019_Movie_List.csv', index=False)

# %% [markdown]
# ### The box office numbers are strings. In order to measure them we need to convert them into integers.

# %%
print(df[df.columns[2:5]].dtypes)
df[df.columns[2:5]]
# Out:
# Worldwide Box Office        object
# Domestic Box Office         object
# International Box Office    object
# dtype: object
#    Worldwide Box Office Domestic Box Office International Box Office
# 0        $2,797,800,564        $858,373,000           $1,939,427,564
# 1        $1,654,381,934        $543,638,043           $1,110,743,891
# 2        $1,447,244,586        $477,373,578             $969,871,008
# 3        $1,131,219,645        $390,532,085             $740,687,560
# 4        $1,129,727,388        $426,829,839             $702,897,549
# ..                  ...                 ...                      ...
# 95          $67,044,017            $478,949              $66,565,068
# 96          $64,686,515         $28,148,130              $36,538,385
# 97          $63,191,904                                  $63,191,904
# 98          $62,599,159         $32,138,862              $30,460,297
# 99          $61,404,394         $31,762,808              $29,641,586
#
# [100 rows x 3 columns]

# %%
#Function to convert string of numbers to integer
def convert_numbers(df):
    for col in df.columns[2:6]:
        df[col]=df[col].str.replace(',','').str.replace('$','').str.replace('%','')
        
    for col in df.columns[2:6]:
        df[col]=df[col].replace('','0')
        
    df['Domestic Share']=df['Domestic Share'].astype(float)
    df['Worldwide Box Office']=df['Worldwide Box Office'].astype(int)
    df['Domestic Box Office']=df['Domestic Box Office'].astype(int)
    df['International Box Office']=df['International Box Office'].astype(int)
    
    return df

# %%
#Assigning the new DataFrame with integers in the place of string numbers
df=convert_numbers(df)

# %%
df
# Out:
#    Rank                                      Movie  Worldwide Box Office  \
# 0     1                          Avengers: Endgame            2797800564
# 1     2                              The Lion King            1654381934
# 2     3                                  Frozen II            1447244586
# 3     4                  Spider-Man: Far From Home            1131219645
# 4     5                             Captain Marvel            1129727388
# ..  ...                                        ...                   ...
# 95   96                                  ek-si-teu              67044017
# 96   97                         Happy Death Day 2U              64686515
# 97   98  Eiga Doraemon: Nobita no Getsumen Tansaki              63191904
# 98   99                               Cold Pursuit              62599159
# 99  100                                  Bombshell              61404394
#
#     Domestic Box Office  International Box Office  Domestic Share
# 0             858373000                1939427564           30.68
# 1             543638043                1110743891           32.86
# 2             477373578                 969871008           32.99
# 3             390532085                 740687560           34.52
# 4             426829839                 702897549           37.78
# ..                  ...                       ...             ...
# 95               478949                  66565068            0.71
# 96             28148130                  36538385           43.51
# 97                    0                  63191904            0.00
# 98             32138862                  30460297           51.34
# 99             31762808                  29641586           51.73
#
# [100 rows x 6 columns]

# %%
#Add International Share to Dataframe
int_share=[]
for num in range(len(df)):
    int_share.append(100 - float(df['Domestic Share'][num]))
df['International Share']=int_share

# %%
df
# Out:
#    Rank                                      Movie  Worldwide Box Office  \
# 0     1                          Avengers: Endgame            2797800564
# 1     2                              The Lion King            1654381934
# 2     3                                  Frozen II            1447244586
# 3     4                  Spider-Man: Far From Home            1131219645
# 4     5                             Captain Marvel            1129727388
# ..  ...                                        ...                   ...
# 95   96                                  ek-si-teu              67044017
# 96   97                         Happy Death Day 2U              64686515
# 97   98  Eiga Doraemon: Nobita no Getsumen Tansaki              63191904
# 98   99                               Cold Pursuit              62599159
# 99  100                                  Bombshell              61404394
#
#     Domestic Box Office  International Box Office  Domestic Share  \
# 0             858373000                1939427564           30.68
# 1             543638043                1110743891           32.86
# 2             477373578                 969871008           32.99
# 3             390532085                 740687560           34.52
# 4             426829839                 702897549           37.78
# ..                  ...                       ...             ...
# 95               478949                  66565068            0.71
# 96             28148130                  36538385           43.51
# 97                    0                  63191904            0.00
# 98             32138862                  30460297           51.34
# 99             31762808                  29641586           51.73
#
#     International Share
# 0                 69.32
# 1                 67.14
# 2                 67.01
# 3                 65.48
# 4                 62.22
# ..                  ...
# 95                99.29
# 96                56.49
# 97               100.00
# 98                48.66
# 99                48.27
#
# [100 rows x 7 columns]

# %%
#Convert Dataframe to CSV File
df.to_csv('2019_Movies_Numbers.csv', index=False)

# %%
#Create list of the links for each movie
links=[]
for l in soup.find('div', id = 'main').findAll('a'):
    if "/movie" in l.get('href'):
        links.append(l.get('href'))
links
# Out:
# ['/movie/Avengers-Endgame-(2019)#tab=summary',
#  '/movie/Lion-King-The-(Live-Action)-(2019)#tab=summary',
#  '/movie/Frozen-II-(2019)#tab=summary',
#  '/movie/Spider-Man-Far-From-Home-(2019)#tab=summary',
#  '/movie/Captain-Marvel-(2019)#tab=summary',
#  '/movie/Toy-Story-4-(2019)#tab=summary',
#  '/movie/Star-Wars-The-Rise-of-Skywalker-(2019)#tab=summary',
#  '/movie/Joker-(2019)#tab=summary',
#  '/movie/Aladdin-(2019)#tab=summary',
#  '/movie/Jumanji-The-Next-Level#tab=summary',
#  '/movie/Fast-and-Furious-Presents-Hobbs-and-Shaw-(2019)#tab=summary',
#  '/movie/Ne-Zha-Zhi-Mo-Tong-Jiang-Shi-(China)#tab=summary',
#  '/movie/Liu-Lang-Di-Qiu-(China)-(2019)#tab=summary',
#  '/movie/How-to-Train-Your-Dragon-The-Hidden-World-(2019)#tab=summary',
#  '/movie/Maleficent-Mistress-of-Evil-(2019)#tab=summary',
#  '/movie/It-Chapter-Two-(2019)#tab=summary',
#  '/movie/Wo-he-wo-de-zu-guo-(China)#tab=summary',
#  '/movie/Secret-Life-of-Pets-2-The-(2019)#tab=summary',
#  '/movie/Pokemon-Detective-Pikachu-(2019)#tab=summary',
#  '/movie/Zhongguo-jizhang-(China)#tab=summary',
#  '/movie/Alita-Battle-Angel-(2019)#tab=summary',
#  '/movie/Godzilla-King-of-the-Monsters-(2019)#tab=summary',
#  '/movie/Once-Upon-a-Time-in-Hollywood-(2019)#tab=summary',
#  '/movie/1917-(2019)#tab=summary',
#  '/movie/Shazam-(2019)#tab=summary',
#  '/movie/Dumbo-(2019)#tab=summary',
#  '/movie/Feng-Kuang-De-Wai-Xing-Ren-(China)(2019)#tab=summary',
#  '/movie/John-Wick-Chapter-3-Parabellum-(2019)#tab=summary',
#  '/movie/Knives-Out-(2019)#tab=summary',
#  '/movie/Us-(2019)#tab=summary',
#  '/movie/Fei-Chi-Ren-Sheng-(China)(2019)#tab=summary',
#  '/movie/gi-saeng-chung-(South-Korea)-(2019)#tab=summary',
#  '/movie/Men-in-Black-International-(2019)#tab=summary',
#  '/movie/Terminator-Dark-Fate-(2019)#tab=summary',
#  '/movie/Glass-(2019)#tab=summary',
#  '/movie/Dark-Phoenix-(2019)#tab=summary',
#  '/movie/Lie-huo-ying-xiong-(China)#tab=summary',
#  '/movie/Shao-Nian-De-Ni-(China)#tab=summary',
#  '/movie/Annabelle-Comes-Home-(2019)#tab=summary',
#  '/movie/Ford-v-Ferrari-(2019)#tab=summary',
#  '/movie/Little-Women-(2019)#tab=summary',
#  '/movie/Addams-Family-The-(2019)#tab=summary',
#  '/movie/Wu-Sha-(China)#tab=summary',
#  '/movie/Downton-Abbey-(UK)-(2019)#tab=summary',
#  '/movie/Yip-Man-4-(Hong-Kong)#tab=summary',
#  '/movie/Rocketman-(UK)-(2019)#tab=summary',
#  '/movie/Tenki-no-Ko-(Japan)#tab=summary',
#  '/movie/Lego-Movie-2-The-Second-Part-The-(2019)#tab=summary',
#  '/movie/Abominable-(2019)#tab=summary',
#  '/movie/White-Storm-2-The-Drug-Lords-(Hong-Kong)#tab=summary',
#  '/movie/Pan-Deng-Zhe-(China)#tab=summary',
#  '/movie/Gemini-Man-(2019)#tab=summary',
#  '/movie/Spies-in-Disguise-(2019)#tab=summary',
#  '/movie/Escape-Room-(2019)#tab=summary',
#  '/movie/Yesterday-(UK)-(2019)#tab=summary',
#  '/movie/Angry-Birds-Movie-2-The-(2019)#tab=summary',
#  '/movie/Hustlers-(2019)#tab=summary',
#  '/movie/Ad-Astra-(2019)#tab=summary',
#  '/movie/Angel-Has-Fallen-(2019)#tab=summary',
#  '/movie/Yin-He-Bu-Xi-Ban-(China)#tab=summary',
#  '/movie/Midway-(2019)#tab=summary',
#  '/movie/Upside-The-(2019)#tab=summary',
#  '/movie/Extreme-Crisis-(China)#tab=summary',
#  '/movie/Last-Christmas-(UK)-(2019)#tab=summary',
#  '/movie/Zombieland-Double-Tap-(2019)#tab=summary',
#  '/movie/Curse-of-La-Llorona-The-(2019)#tab=summary',
#  '/movie/Meitantei-Conan-Konjo-no-Fisuto-(Japan)-(2019)#tab=summary',
#  '/movie/Dora-and-the-Lost-City-of-Gold-(2019)#tab=summary',
#  '/movie/Geukhanjikeob-(S-Korea)-(2019)#tab=summary',
#  '/movie/Fan-Tan-Feng-Bao-4-(China)(2019)#tab=summary',
#  '/movie/Wonder-Park-(2019)#tab=summary',
#  '/movie/Gentlemen-The#tab=summary',
#  '/movie/Boonie-Bears-Blast-Into-The-Past-(China)(2019)#tab=summary',
#  '/movie/Pet-Sematary-(2019)#tab=summary',
#  '/movie/Good-Boys-(2019)#tab=summary',
#  '/movie/Chong-Ai-(China)#tab=summary',
#  '/movie/Shi-Tu-Xing-Zhe-2-Die-Ying-Xing-Dong-(China)#tab=summary',
#  '/movie/Hustle-The-(2019)#tab=summary',
#  '/movie/Scary-Stories-to-Tell-in-the-Dark-(2019)#tab=summary',
#  '/movie/Xin-xiju-zhi-wang-(China)(2019)#tab=summary',
#  '/movie/Five-Feet-Apart-(2019)#tab=summary',
#  '/movie/Rambo-Last-Blood-(2019)#tab=summary',
#  '/movie/Crawl-(2019)#tab=summary',
#  '/movie/Jojo-Rabbit-(Germany)-(2019)#tab=summary',
#  '/movie/Wan-Pisu-Sutanpdo-(Japan)#tab=summary',
#  '/movie/Dogs-Way-Home-A-(2019)#tab=summary',
#  '/movie/Dogs-Journey-A-(2019)#tab=summary',
#  '/movie/Cats-(2019)#tab=summary',
#  '/movie/Tyler-Perrys-A-Madea-Family-Funeral-(2019)#tab=summary',
#  '/movie/Qu-est-ce-qu-on-a-encore-fait-au-bon-dieu-(France)-(2019)#tab=summary',
#  '/movie/Charlies-Angels-(2019)#tab=summary',
#  '/movie/Doctor-Sleep-(2019)#tab=summary',
#  '/movie/What-Men-Want-(2019)#tab=summary',
#  '/movie/Beautiful-Day-in-the-Neighborhood-A-(2019)#tab=summary',
#  '/movie/Bai-she-yuan-qi-(China)(2019)#tab=summary',
#  '/movie/ek-si-teu-(South-Korea)#tab=summary',
#  '/movie/Happy-Death-Day-2U-(2019)#tab=summary',
#  '/movie/Eiga-Doraemon-Nobita-no-Getsumen-Tansaki-(South-Korea)-(2019)#tab=summary',
#  '/movie/Cold-Pursuit-(2019)#tab=summary',
#  '/movie/Bombshell#tab=summary']

# %%
#Function to scrape each movie's page to see if it's a part of a franchise, re-make (nastalgia), or sequel
def franchise(url): 
    response2 = requests.get(url)
    soup2 = BeautifulSoup(response2.content, 'html.parser')
    for name in soup2.find('div', id = 'summary').findAll('td'): 
        if "Franchise" in name.text or "Remake" in name.text:
            return 'Yes'
    return 'No'

# %%
#Creating new series in the dataframe called 'Franchise' to identify movies a part of a Franchise
fran=[]
for l in links: 
    url = 'https://www.the-numbers.com/' + l
    fran.append(franchise(url))
df['Franchise'] = fran

# %%
#Convert Dataframe to CSV File
df.to_csv('2019_Franchise_Numbers.csv', index=False)

# %%
#Function to pull the ratings from the movie web pages
def rating(url): 
    response3 = requests.get(url)
    soup3 = BeautifulSoup(response3.content, 'html.parser')
    for rate in soup3.find('div', id = 'summary').findAll('a', href=True, text=['PG','PG-13','Not Rated','R','G']):
        return rate.text

# %%
#Adding the MPAA Ratings to the dataframe
ratings=[]
for l in links: 
    url = 'https://www.the-numbers.com/' + l
    ratings.append(rating(url))
df['MPAA Rating'] = ratings

# %%
#Replace the NaN with 'N/A'
df = df.fillna('N/A')

# %%
df
# Out:
#    Rank                                      Movie  Worldwide Box Office  \
# 0     1                          Avengers: Endgame            2797800564
# 1     2                              The Lion King            1654381934
# 2     3                                  Frozen II            1447244586
# 3     4                  Spider-Man: Far From Home            1131219645
# 4     5                             Captain Marvel            1129727388
# ..  ...                                        ...                   ...
# 95   96                                  ek-si-teu              67044017
# 96   97                         Happy Death Day 2U              64686515
# 97   98  Eiga Doraemon: Nobita no Getsumen Tansaki              63191904
# 98   99                               Cold Pursuit              62599159
# 99  100                                  Bombshell              61404394
#
#     Domestic Box Office  International Box Office  Domestic Share  \
# 0             858373000                1939427564           30.68
# 1             543638043                1110743891           32.86
# 2             477373578                 969871008           32.99
# 3             390532085                 740687560           34.52
# 4             426829839                 702897549           37.78
# ..                  ...                       ...             ...
# 95               478949                  66565068            0.71
# 96             28148130                  36538385           43.51
# 97                    0                  63191904            0.00
# 98             32138862                  30460297           51.34
# 99             31762808                  29641586           51.73
#
#     International Share Franchise MPAA Rating
# 0                 69.32       Yes       PG-13
# 1                 67.14       Yes          PG
# 2                 67.01       Yes          PG
# 3                 65.48       Yes       PG-13
# 4                 62.22       Yes       PG-13
# ..                  ...       ...         ...
# 95                99.29        No   Not Rated
# 96                56.49       Yes       PG-13
# 97               100.00        No         N/A
# 98                48.66       Yes           R
# 99                48.27        No           R
#
# [100 rows x 9 columns]

# %%
#Convert Dataframe to CSV File
df.to_csv('_2019_MPAA_Numbers.csv', index=False)
