# %% [markdown]
# # Phase 1 Final Project - MicroFilms Presentation

# %% [markdown]
# ![alt text](https://fuse.wustl.edu/wp-content/uploads/2017/03/Microsoft-1918x768.jpeg")

# %% [markdown]
# Microsoft sees all the big companies creating original video content, and they want to get in on the fun. They have decided to create a new movie studio, but the problem is they don’t know anything about creating movies. They have hired you to help them better understand the movie industry. Your team is charged with doing data analysis and creating a presentation that explores what type of films are currently doing the best at the box office. You must then translate those findings into actionable insights that the CEO can use when deciding what type of films they should be creating.

# %% [markdown]
# - What movies have the highest foreign percentage and the highest foreign gross numbers?
# - How many of the top grossing movies are a part of a franchise, sequel or nostalgia?
# - What are the highest grossing MPAA ratings?

# %%
#Import libraries
import requests 
from bs4 import BeautifulSoup
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import seaborn as sns
import csv
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# ### We'll start by using the scraped 2019 Box Office Records from www.the-numbers.com

# %%
df = pd.read_csv('Data/2019_Movie_List.csv')

# %%
df
# Out:
#     Rank                                      Movie Worldwide Box Office  \
# 0      1                          Avengers: Endgame       $2,797,800,564
# 1      2                              The Lion King       $1,654,381,934
# 2      3                                  Frozen II       $1,447,244,586
# 3      4                  Spider-Man: Far From Home       $1,131,219,645
# 4      5                             Captain Marvel       $1,129,727,388
# ..   ...                                        ...                  ...
# 95    96                                  ek-si-teu          $67,044,017
# 96    97                         Happy Death Day 2U          $64,686,515
# 97    98  Eiga Doraemon: Nobita no Getsumen Tansaki          $63,191,904
# 98    99                               Cold Pursuit          $62,599,159
# 99   100                                  Bombshell          $61,404,394
#
#    Domestic Box Office International Box Office Domestic Share
# 0         $858,373,000           $1,939,427,564         30.68%
# 1         $543,638,043           $1,110,743,891         32.86%
# 2         $477,373,578             $969,871,008         32.99%
# 3         $390,532,085             $740,687,560         34.52%
# 4         $426,829,839             $702,897,549         37.78%
# ..                 ...                      ...            ...
# 95            $478,949              $66,565,068          0.71%
# 96         $28,148,130              $36,538,385         43.51%
# 97                 NaN              $63,191,904            NaN
# 98         $32,138,862              $30,460,297         51.34%
# 99         $31,762,808              $29,641,586         51.73%
#
# [100 rows x 6 columns]

# %% [markdown]
# ## What movies have the highest foreign percentage and the highest foreign gross numbers?

# %% [markdown]
# ### Let's create an International Share to show the percentage of the Worldwide Box Office comes from International Box Office as well as convert the numbers into integers.

# %%
df = pd.read_csv('Data/2019_Movies_Numbers.csv') 
df
# Out:
#     Rank                                      Movie  Worldwide Box Office  \
# 0      1                          Avengers: Endgame            2797800564
# 1      2                              The Lion King            1654381934
# 2      3                                  Frozen II            1447244586
# 3      4                  Spider-Man: Far From Home            1131219645
# 4      5                             Captain Marvel            1129727388
# ..   ...                                        ...                   ...
# 95    96                                  ek-si-teu              67044017
# 96    97                         Happy Death Day 2U              64686515
# 97    98  Eiga Doraemon: Nobita no Getsumen Tansaki              63191904
# 98    99                               Cold Pursuit              62599159
# 99   100                                  Bombshell              61404394
#
#     Domestic Box Office  International Box Office  Domestic Share  \
# 0             858373000                1939427564           30.68
# 1             543638043                1110743891           32.86
# 2             477373578                 969871008           32.99
# 3             390532085                 740687560           34.52
# 4             426829839                 702897549           37.78
# ..                  ...                       ...             ...
# 95               478949                  66565068            0.71
# 96             28148130                  36538385           43.51
# 97                    0                  63191904            0.00
# 98             32138862                  30460297           51.34
# 99             31762808                  29641586           51.73
#
#     International Share
# 0                 69.32
# 1                 67.14
# 2                 67.01
# 3                 65.48
# 4                 62.22
# ..                  ...
# 95                99.29
# 96                56.49
# 97               100.00
# 98                48.66
# 99                48.27
#
# [100 rows x 7 columns]

# %%
#Try a density plot
sns.set(style="dark", font_scale=1.5, rc={'figure.figsize':(11.7,8.27)})
sns.distplot(df['International Share'],
             color='crimson');

# %% [markdown]
# ## Key Takeaway
# A majority of the Box Office money is made International

# %% [markdown]
# ___________________________________________________________________________________________________________
#
# # How many of the top grossing movies are a part of a franchise, sequel or nostalgia?

# %% [markdown]
# ### First we'll identify the movies that are a part of a franchise, sequel or nostalgia?

# %%
df_franchise = pd.read_csv('Data/2019_Franchise_Numbers.csv')

# %%
df_franchise
# Out:
#     Rank                                      Movie  Worldwide Box Office  \
# 0      1                          Avengers: Endgame            2797800564
# 1      2                              The Lion King            1654381934
# 2      3                                  Frozen II            1447244586
# 3      4                  Spider-Man: Far From Home            1131219645
# 4      5                             Captain Marvel            1129727388
# ..   ...                                        ...                   ...
# 95    96                                  ek-si-teu              67044017
# 96    97                         Happy Death Day 2U              64686515
# 97    98  Eiga Doraemon: Nobita no Getsumen Tansaki              63191904
# 98    99                               Cold Pursuit              62599159
# 99   100                                  Bombshell              61404394
#
#     Domestic Box Office  International Box Office  Domestic Share  \
# 0             858373000                1939427564           30.68
# 1             543638043                1110743891           32.86
# 2             477373578                 969871008           32.99
# 3             390532085                 740687560           34.52
# 4             426829839                 702897549           37.78
# ..                  ...                       ...             ...
# 95               478949                  66565068            0.71
# 96             28148130                  36538385           43.51
# 97                    0                  63191904            0.00
# 98             32138862                  30460297           51.34
# 99             31762808                  29641586           51.73
#
#     International Share Franchise
# 0                 69.32       Yes
# 1                 67.14       Yes
# 2                 67.01       Yes
# 3                 65.48       Yes
# 4                 62.22       Yes
# ..                  ...       ...
# 95                99.29        No
# 96                56.49       Yes
# 97               100.00        No
# 98                48.66       Yes
# 99                48.27        No
#
# [100 rows x 8 columns]

# %% [markdown]
# ### Next we'll evaluate the Box Office numbers of the movies a part of a franchise, nostalgia, and sequel vs. the movies that don't fall under any of these categories.

# %%
df_franchise_agg = {}
for bo in df_franchise.columns[2:5]: 
    df_franchise_agg[bo] = df_franchise.groupby('Franchise')[bo].mean()
    
df_franchise_agg = pd.DataFrame(df_franchise_agg)

# %%
df_franchise_agg.plot(kind='bar', figsize=(9,8))
plt.xticks(rotation=0)
plt.ylabel('In Hundreds of Millions')
plt.title('Franchise vs Non-Franchise Box Office Numbers');

# %% [markdown]
# ## Key Takeaway
# Movies that are a part of a franchise do significantly better in both Internationally and Domestically.

# %% [markdown]
# ___________________________________________________________________________________________________________
#
# ### What if Microsoft wants to produce a movie without a franchise?

# %%
#Dataframe without the Franchise movies
df_franchise[df_franchise['Franchise'] == 'No']
# Out:
#     Rank                                       Movie  Worldwide Box Office  \
# 11    12                Ne Zha Zhi Mo Tong Jiang Shi             742514069
# 12    13                             Liu Lang Di Qiu             727714822
# 16    17                          Wo he wo de zu guo             465418019
# 19    20                            Zhongguo jizhang             417850370
# 20    21                         Alita: Battle Angel             401900040
# 22    23             Once Upon a Timeâ¦in Hollywood             377312380
# 23    24                                        1917             366890181
# 26    27                  Feng Kuang De Wai Xing Ren             326150303
# 29    30                                          Us             256091919
# 30    31                           Fei Chi Ren Sheng             255832826
# 31    32                                Gisaengchung             254688898
# 36    37                          Lie huo ying xiong             245179530
# 37    38                             Shao Nian De Ni             230096929
# 39    40                             Ford v. Ferrari             224418748
# 40    41                                Little Women             218786590
# 41    42                           The Addams Family             200612027
# 42    43                                      Wu Sha             199276793
# 45    46                                   Rocketman             192137020
# 46    47                                 Tenki no Ko             190527439
# 48    49                                  Abominable             188125862
# 49    50               The White Storm 2: Drug Lords             185427900
# 50    51                                Pan Deng Zhe             171110959
# 51    52                                  Gemini Man             166623705
# 52    53                           Spies in Disguise             165139629
# 53    54                                 Escape Room             155313078
# 54    55                                   Yesterday             153108647
# 56    57                                    Hustlers             150472713
# 57    58                                    Ad Astra             135432019
# 59    60                            Yin He Bu Xi Ban             127897924
# 60    61                                      Midway             126151409
# 62    63                              Extreme Crisis             124169976
# 63    64                              Last Christmas             123432533
# 66    67            Meitantei Conan: Konjo no Fisuto             117888768
# 67    68              Dora and the Lost City of Gold             117419117
# 68    69                               Geukhanjikeob             116127561
# 69    70                          Fan Tan Feng Bao 4             115687407
# 70    71                                 Wonder Park             115112118
# 71    72                               The Gentlemen             113876604
# 74    75                                   Good Boys             111173598
# 75    76                                    Chong Ai              99550121
# 76    77        Shi Tu Xing Zhe 2 Die Ying Xing Dong              98444408
# 78    79           Scary Stories to Tell in the Dark              95607360
# 79    80                      XÄ«n xÇjÃ¹ zhÄ« wÃ¡ng              92796952
# 80    81                             Five Feet Apart              92554209
# 82    83                                       Crawl              90007532
# 83    84                                 Jojo Rabbit              87068472
# 84    85                        Wan PÄ«su SutanpÄ«do              84372709
# 85    86                          A Dogâs Way Home              81152505
# 87    88                                        Cats              75486351
# 89    90  Qu'est-ce qu'on a encore fait au bon dieu?              74766188
# 93    94         A Beautiful Day in the Neighborhood              68406338
# 94    95                            Bai She: Yuan Qi              68364730
# 95    96                                   ek-si-teu              67044017
# 97    98   Eiga Doraemon: Nobita no Getsumen Tansaki              63191904
# 99   100                                   Bombshell              61404394
#
#     Domestic Box Office  International Box Office  Domestic Share  \
# 11              3695533                 738818536            0.50
# 12              5875487                 721839335            0.81
# 16              2323409                 463094610            0.50
# 19               706572                 417143798            0.17
# 20             85838210                 316061830           21.36
# 22            142502728                 234809652           37.77
# 23            159227644                 207662537           43.40
# 26                    0                 326150303            0.00
# 29            175084580                  81007339           68.37
# 30                    0                 255832826            0.00
# 31             53369745                 201319153           20.95
# 36               290217                 244889313            0.12
# 37              1921657                 228175272            0.84
# 39            117624357                 106794391           52.41
# 40            108095955                 110690635           49.41
# 41             97864733                 102747294           48.78
# 42                    0                 199276793            0.00
# 45             96368160                  95768860           50.16
# 46              7798703                 182728736            4.09
# 48             60761390                 127364472           32.30
# 49                    0                 185427900            0.00
# 50               487157                 170623802            0.28
# 51             48546770                 118076935           29.14
# 52             66757013                  98382616           40.42
# 53             57000756                  98312322           36.70
# 54             73286650                  79821997           47.87
# 56            104963598                  45509115           69.76
# 57             50188370                  85243649           37.06
# 59                    0                 127897924            0.00
# 60             56846802                  69304607           45.06
# 62                    0                 124169976            0.00
# 63             35150750                  88281783           28.48
# 66                    0                 117888768            0.00
# 67             60477943                  56941174           51.51
# 68              1565885                 114561676            1.35
# 69                    0                 115687407            0.00
# 70             45216793                  69895325           39.28
# 71             36471796                  77404808           32.03
# 74             83140306                  28033292           74.78
# 75                    0                  99550121            0.00
# 76               296751                  98147657            0.30
# 78             68947075                  26660285           72.11
# 79                    0                  92796952            0.00
# 80             45729221                  46824988           49.41
# 82             39014193                  50993339           43.35
# 83             33370906                  53697566           38.33
# 84                    0                  84372709            0.00
# 85             41952715                  39199790           51.70
# 87             27166770                  48319581           35.99
# 89                    0                  74766188            0.00
# 93             61696436                   6709902           90.19
# 94                34730                  68330000            0.05
# 95               478949                  66565068            0.71
# 97                    0                  63191904            0.00
# 99             31762808                  29641586           51.73
#
#     International Share Franchise
# 11                99.50        No
# 12                99.19        No
# 16                99.50        No
# 19                99.83        No
# 20                78.64        No
# 22                62.23        No
# 23                56.60        No
# 26               100.00        No
# 29                31.63        No
# 30               100.00        No
# 31                79.05        No
# 36                99.88        No
# 37                99.16        No
# 39                47.59        No
# 40                50.59        No
# 41                51.22        No
# 42               100.00        No
# 45                49.84        No
# 46                95.91        No
# 48                67.70        No
# 49               100.00        No
# 50                99.72        No
# 51                70.86        No
# 52                59.58        No
# 53                63.30        No
# 54                52.13        No
# 56                30.24        No
# 57                62.94        No
# 59               100.00        No
# 60                54.94        No
# 62               100.00        No
# 63                71.52        No
# 66               100.00        No
# 67                48.49        No
# 68                98.65        No
# 69               100.00        No
# 70                60.72        No
# 71                67.97        No
# 74                25.22        No
# 75               100.00        No
# 76                99.70        No
# 78                27.89        No
# 79               100.00        No
# 80                50.59        No
# 82                56.65        No
# 83                61.67        No
# 84               100.00        No
# 85                48.30        No
# 87                64.01        No
# 89               100.00        No
# 93                 9.81        No
# 94                99.95        No
# 95                99.29        No
# 97               100.00        No
# 99                48.27        No

# %%
df_franchise.groupby('Franchise')['International Share'].mean().plot(kind='bar',
                                                                     figsize=(9,8),
                                                                     color='deepskyblue')
plt.xticks(rotation=0)
plt.ylabel('Percentage of International Share')
plt.title('Franchise vs Non-Franchise International Share');

# %% [markdown]
# ## Key Takeaway
# Non-Franchise movies have a significant amount of international box office account for their success.

# %% [markdown]
# ___________________________________________________________________________________________________________
#
# ## What are the highest grossing MPAA ratings?

# %% [markdown]
# ### Let's start by pulling the ratings from the different movie pages.

# %%
df_mpaa = pd.read_csv('Data/_2019_MPAA_Numbers.csv').fillna('N/A')

# %%
df_mpaa
# Out:
#     Rank                                      Movie  Worldwide Box Office  \
# 0      1                          Avengers: Endgame            2797800564
# 1      2                              The Lion King            1654381934
# 2      3                                  Frozen II            1447244586
# 3      4                  Spider-Man: Far From Home            1131219645
# 4      5                             Captain Marvel            1129727388
# ..   ...                                        ...                   ...
# 95    96                                  ek-si-teu              67044017
# 96    97                         Happy Death Day 2U              64686515
# 97    98  Eiga Doraemon: Nobita no Getsumen Tansaki              63191904
# 98    99                               Cold Pursuit              62599159
# 99   100                                  Bombshell              61404394
#
#     Domestic Box Office  International Box Office  Domestic Share  \
# 0             858373000                1939427564           30.68
# 1             543638043                1110743891           32.86
# 2             477373578                 969871008           32.99
# 3             390532085                 740687560           34.52
# 4             426829839                 702897549           37.78
# ..                  ...                       ...             ...
# 95               478949                  66565068            0.71
# 96             28148130                  36538385           43.51
# 97                    0                  63191904            0.00
# 98             32138862                  30460297           51.34
# 99             31762808                  29641586           51.73
#
#     International Share Franchise MPAA Rating
# 0                 69.32       Yes       PG-13
# 1                 67.14       Yes          PG
# 2                 67.01       Yes          PG
# 3                 65.48       Yes       PG-13
# 4                 62.22       Yes       PG-13
# ..                  ...       ...         ...
# 95                99.29        No   Not Rated
# 96                56.49       Yes       PG-13
# 97               100.00        No         N/A
# 98                48.66       Yes           R
# 99                48.27        No           R
#
# [100 rows x 9 columns]

# %% [markdown]
# ### Now let's find out which ratings actually earned the most average amount of money in the box office

# %%
avg_box_off = df_mpaa.groupby('MPAA Rating')['Worldwide Box Office'].mean().sort_values(ascending=False)

# %%
avg_box_off.plot(kind='bar', figsize=(10,6), color='mediumslateblue')
plt.title('MPAA Rating Average Box Office', fontsize='20')
plt.ylabel('Box Office By Hundred Millions', fontsize='18')
plt.xlabel('MPAA Ratings', fontsize='18')
plt.xticks(fontsize='14', rotation=-45)
plt.yticks(fontsize='14');

# %% [markdown]
# ## Key Takeaway
# MPAA Rating G is by far the highest grossing genre.
